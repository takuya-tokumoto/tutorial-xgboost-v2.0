# %% [markdown]
# # A demo for multi-output regression
#
# The demo is adopted from scikit-learn:
#
# https://scikit-learn.org/stable/auto_examples/ensemble/plot_random_forest_regression_multioutput.html#sphx-glr-auto-examples-ensemble-plot-random-forest-regression-multioutput-py
#
# See :doc:`/tutorials/multioutput` for more information.
#
# <div class="alert alert-info"><h4>Note</h4><p>The feature is experimental. For the `multi_output_tree` strategy, many features are
#     missing.</p></div>

# %%
import argparse
from typing import Dict, List, Tuple

import numpy as np
from matplotlib import pyplot as plt

import xgboost as xgb
print(xgb.__version__)


def plot_predt(y: np.ndarray, y_predt: np.ndarray, name: str) -> None:
    s = 25
    plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="data")
    plt.scatter(
        y_predt[:, 0], y_predt[:, 1], c="cornflowerblue", s=s, edgecolor="black"
    )
    plt.xlim([-1, 2])
    plt.ylim([-1, 2])
    plt.show()


def gen_circle() -> Tuple[np.ndarray, np.ndarray]:
    "yが2次元の円であるサンプルデータセットを生成する"
    rng = np.random.RandomState(1994)
    X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
    y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
    y[::5, :] += 0.5 - rng.rand(20, 2)
    y = y - y.min()
    y = y / y.max()
    return X, y


def rmse_model(plot_result: bool, strategy: str) -> None:
    """2次元座標をターゲット変数として円を描く"""
    X, y = gen_circle()
    # Train a regressor on it
    reg = xgb.XGBRegressor(
        tree_method="hist",
        n_estimators=128,
        n_jobs=16,
        max_depth=8,
        multi_strategy=strategy,
        subsample=0.6,
    )
    reg.fit(X, y, eval_set=[(X, y)])

    y_predt = reg.predict(X)
    if plot_result:
        plot_predt(y, y_predt, "multi")


def custom_rmse_model(plot_result: bool, strategy: str) -> None:
    """PythonのSquared Errorの実装を使って学習"""

    # As the experimental support status, custom objective doesn't support matrix as
    # gradient and hessian, which will be changed in future release.
    def gradient(predt: np.ndarray, dtrain: xgb.DMatrix) -> np.ndarray:
        """Compute the gradient squared error."""
        y = dtrain.get_label().reshape(predt.shape)
        return (predt - y).reshape(y.size)

    def hessian(predt: np.ndarray, dtrain: xgb.DMatrix) -> np.ndarray:
        """Compute the hessian for squared error."""
        return np.ones(predt.shape).reshape(predt.size)

    def squared_log(
        predt: np.ndarray, dtrain: xgb.DMatrix
    ) -> Tuple[np.ndarray, np.ndarray]:
        grad = gradient(predt, dtrain)
        hess = hessian(predt, dtrain)
        return grad, hess

    def rmse(predt: np.ndarray, dtrain: xgb.DMatrix) -> Tuple[str, float]:
        y = dtrain.get_label().reshape(predt.shape)
        v = np.sqrt(np.sum(np.power(y - predt, 2)))
        return "PyRMSE", v

    X, y = gen_circle()
    Xy = xgb.DMatrix(X, y)
    results: Dict[str, Dict[str, List[float]]] = {}
    # Make sure the `num_target` is passed to XGBoost when custom objective is used.
    # When builtin objective is used, XGBoost can figure out the number of targets
    # automatically.
    booster = xgb.train(
        {
            "tree_method": "hist",
            "num_target": y.shape[1],
            "multi_strategy": strategy,
        },
        dtrain=Xy,
        num_boost_round=128,
        obj=squared_log,
        evals=[(Xy, "Train")],
        evals_result=results,
        custom_metric=rmse,
    )

    y_predt = booster.inplace_predict(X)
    if plot_result:
        plot_predt(y, y_predt, "multi")


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--plot", choices=[0, 1], type=int, default=1)
    # args = parser.parse_args()

    args, _ = parser.parse_known_args()

    # Train with builtin RMSE objective
    # - One model per output.
    # rmse_model(args.plot == 1, "one_output_per_tree")
    rmse_model(True, "one_output_per_tree")
    # - One model for all outputs, this is still working in progress, many features are
    # missing.
    rmse_model(args.plot == 1, "multi_output_tree")

    # Train with custom objective.
    # - One model per output.
    custom_rmse_model(args.plot == 1, "one_output_per_tree")
    # - One model for all outputs, this is still working in progress, many features are
    # missing.
    custom_rmse_model(args.plot == 1, "multi_output_tree")
# Out:
# 2.0.0
# [0]	validation_0-rmse:0.29417
# [1]	validation_0-rmse:0.26360
# [2]	validation_0-rmse:0.23619
# [3]	validation_0-rmse:0.22068
# [4]	validation_0-rmse:0.20681
# [5]	validation_0-rmse:0.19295
# [6]	validation_0-rmse:0.17849
# [7]	validation_0-rmse:0.16562
# [8]	validation_0-rmse:0.15492
# [9]	validation_0-rmse:0.14493
# [10]	validation_0-rmse:0.13892
# [11]	validation_0-rmse:0.13172
# [12]	validation_0-rmse:0.12253
# [13]	validation_0-rmse:0.11744
# [14]	validation_0-rmse:0.10981
# [15]	validation_0-rmse:0.10176
# [16]	validation_0-rmse:0.09476
# [17]	validation_0-rmse:0.08947
# [18]	validation_0-rmse:0.08399
# [19]	validation_0-rmse:0.07952
# [20]	validation_0-rmse:0.07442
# [21]	validation_0-rmse:0.07048
# [22]	validation_0-rmse:0.06749
# [23]	validation_0-rmse:0.06505
# [24]	validation_0-rmse:0.06060
# [25]	validation_0-rmse:0.05737
# [26]	validation_0-rmse:0.05539
# [27]	validation_0-rmse:0.05326
# [28]	validation_0-rmse:0.05026
# [29]	validation_0-rmse:0.04692
# [30]	validation_0-rmse:0.04501
# [31]	validation_0-rmse:0.04175
# [32]	validation_0-rmse:0.03970
# [33]	validation_0-rmse:0.03683
# [34]	validation_0-rmse:0.03430
# [35]	validation_0-rmse:0.03219
# [36]	validation_0-rmse:0.03058
# [37]	validation_0-rmse:0.02914
# [38]	validation_0-rmse:0.02778
# [39]	validation_0-rmse:0.02611
# [40]	validation_0-rmse:0.02504
# [41]	validation_0-rmse:0.02322
# [42]	validation_0-rmse:0.02212
# [43]	validation_0-rmse:0.02129
# [44]	validation_0-rmse:0.01992
# [45]	validation_0-rmse:0.01930
# [46]	validation_0-rmse:0.01864
# [47]	validation_0-rmse:0.01744
# [48]	validation_0-rmse:0.01618
# [49]	validation_0-rmse:0.01521
# [50]	validation_0-rmse:0.01428
# [51]	validation_0-rmse:0.01346
# [52]	validation_0-rmse:0.01276
# [4]	validation_0-rmse:0.20795
# [5]	validation_0-rmse:0.19109
# [6]	validation_0-rmse:0.17936
# [7]	validation_0-rmse:0.17053
# [8]	validation_0-rmse:0.16198
# [9]	validation_0-rmse:0.15406
# [10]	validation_0-rmse:0.14510
# [11]	validation_0-rmse:0.13641
# [12]	validation_0-rmse:0.12550
# [13]	validation_0-rmse:0.11761
# [14]	validation_0-rmse:0.11132
# [15]	validation_0-rmse:0.10186
# [16]	validation_0-rmse:0.09376
# [17]	validation_0-rmse:0.08897
# [18]	validation_0-rmse:0.08226
# [19]	validation_0-rmse:0.07742
# [20]	validation_0-rmse:0.07209
# [21]	validation_0-rmse:0.06959
# [22]	validation_0-rmse:0.06703
# [23]	validation_0-rmse:0.06274
# [24]	validation_0-rmse:0.05932
# [25]	validation_0-rmse:0.05540
# [26]	validation_0-rmse:0.05157
# [27]	validation_0-rmse:0.04830
# [28]	validation_0-rmse:0.04540
# [29]	validation_0-rmse:0.04313
# [30]	validation_0-rmse:0.04098
# [31]	validation_0-rmse:0.03869
# [32]	validation_0-rmse:0.03728
# [33]	validation_0-rmse:0.03536
# [34]	validation_0-rmse:0.03372
# [35]	validation_0-rmse:0.03235
# [36]	validation_0-rmse:0.03092
# [37]	validation_0-rmse:0.02888
# [38]	validation_0-rmse:0.02685
# [39]	validation_0-rmse:0.02546
# [40]	validation_0-rmse:0.02371
# [41]	validation_0-rmse:0.02209
# [42]	validation_0-rmse:0.02130
# [43]	validation_0-rmse:0.02008
# [44]	validation_0-rmse:0.01901
# [45]	validation_0-rmse:0.01851
# [46]	validation_0-rmse:0.01714
# [47]	validation_0-rmse:0.01648
# [48]	validation_0-rmse:0.01586
# [49]	validation_0-rmse:0.01494
# [50]	validation_0-rmse:0.01375
# [51]	validation_0-rmse:0.01313
# [52]	validation_0-rmse:0.01259
# [53]	validation_0-rmse:0.01192
# [54]	validation_0-rmse:0.01145
# [55]	validation_0-rmse:0.01088
# [56]	validation_0-rmse:0.01024
# [57]	validation_0-rmse:0.00954
# [58]	validation_0-rmse:0.00876
# [59]	validation_0-rmse:0.00825
# [60]	validation_0-rmse:0.00776
# [61]	validation_0-rmse:0.00736
# [62]	validation_0-rmse:0.00694
# [63]	validation_0-rmse:0.00652
# [64]	validation_0-rmse:0.00609
# [65]	validation_0-rmse:0.00589
# [66]	validation_0-rmse:0.00570
# [67]	validation_0-rmse:0.00529
# [68]	validation_0-rmse:0.00491
# [69]	validation_0-rmse:0.00470
# [70]	validation_0-rmse:0.00449
# [71]	validation_0-rmse:0.00422
# [72]	validation_0-rmse:0.00398
# [73]	validation_0-rmse:0.00373
# [74]	validation_0-rmse:0.00346
# [75]	validation_0-rmse:0.00329
# [76]	validation_0-rmse:0.00311
# [77]	validation_0-rmse:0.00299
# [78]	validation_0-rmse:0.00283
# [79]	validation_0-rmse:0.00271
# [80]	validation_0-rmse:0.00263
# [81]	validation_0-rmse:0.00250
# [82]	validation_0-rmse:0.00236
# [83]	validation_0-rmse:0.00219
# [84]	validation_0-rmse:0.00215
# [85]	validation_0-rmse:0.00206
# [86]	validation_0-rmse:0.00195
# [87]	validation_0-rmse:0.00187
# [88]	validation_0-rmse:0.00177
# [89]	validation_0-rmse:0.00166
# [90]	validation_0-rmse:0.00157
# [91]	validation_0-rmse:0.00151
# [92]	validation_0-rmse:0.00142
# [93]	validation_0-rmse:0.00135
# [94]	validation_0-rmse:0.00126
# [95]	validation_0-rmse:0.00121
# [96]	validation_0-rmse:0.00118
# [97]	validation_0-rmse:0.00110
# [98]	validation_0-rmse:0.00103
# [99]	validation_0-rmse:0.00097
# [100]	validation_0-rmse:0.00092
# [101]	validation_0-rmse:0.00091
# [102]	validation_0-rmse:0.00089
# [103]	validation_0-rmse:0.00086
# [104]	validation_0-rmse:0.00082
# [105]	validation_0-rmse:0.00082
# [106]	validation_0-rmse:0.00079
# [107]	validation_0-rmse:0.00075
# [108]	validation_0-rmse:0.00074
# [109]	validation_0-rmse:0.00074
# [110]	validation_0-rmse:0.00072
# [111]	validation_0-rmse:0.00071
# [112]	validation_0-rmse:0.00068
# [113]	validation_0-rmse:0.00068
# [114]	validation_0-rmse:0.00068
# [115]	validation_0-rmse:0.00067
# [116]	validation_0-rmse:0.00066
# [117]	validation_0-rmse:0.00064
# [118]	validation_0-rmse:0.00063
# [119]	validation_0-rmse:0.00063
# [120]	validation_0-rmse:0.00061
# [121]	validation_0-rmse:0.00061
# [122]	validation_0-rmse:0.00060
# [123]	validation_0-rmse:0.00059
# [124]	validation_0-rmse:0.00059
# [125]	validation_0-rmse:0.00059
# [126]	validation_0-rmse:0.00059
# [127]	validation_0-rmse:0.00059
# [0]	Train-rmse:0.28597	Train-PyRMSE:4.04424
# [1]	Train-rmse:0.25494	Train-PyRMSE:3.60534
# [2]	Train-rmse:0.23359	Train-PyRMSE:3.30341
# [3]	Train-rmse:0.21640	Train-PyRMSE:3.06038
# [4]	Train-rmse:0.20574	Train-PyRMSE:2.90962
# [5]	Train-rmse:0.19311	Train-PyRMSE:2.73098
# [6]	Train-rmse:0.18435	Train-PyRMSE:2.60710
# [7]	Train-rmse:0.17502	Train-PyRMSE:2.47516
# [8]	Train-rmse:0.16830	Train-PyRMSE:2.38017
# [9]	Train-rmse:0.15957	Train-PyRMSE:2.25667
# [10]	Train-rmse:0.15430	Train-PyRMSE:2.18211
# [11]	Train-rmse:0.14604	Train-PyRMSE:2.06533
# [12]	Train-rmse:0.13629	Train-PyRMSE:1.92740
# [13]	Train-rmse:0.13249	Train-PyRMSE:1.87376
# [14]	Train-rmse:0.12557	Train-PyRMSE:1.77588
# [15]	Train-rmse:0.12198	Train-PyRMSE:1.72505
# [16]	Train-rmse:0.11972	Train-PyRMSE:1.69314
# [17]	Train-rmse:0.11345	Train-PyRMSE:1.60444
# [18]	Train-rmse:0.10926	Train-PyRMSE:1.54524
# [19]	Train-rmse:0.10367	Train-PyRMSE:1.46616
# [67]	Train-rmse:0.01861	Train-PyRMSE:0.26320
# [68]	Train-rmse:0.01835	Train-PyRMSE:0.25955
# [69]	Train-rmse:0.01763	Train-PyRMSE:0.24935
# [70]	Train-rmse:0.01697	Train-PyRMSE:0.24001
# [71]	Train-rmse:0.01633	Train-PyRMSE:0.23098
# [72]	Train-rmse:0.01582	Train-PyRMSE:0.22368
# [73]	Train-rmse:0.01562	Train-PyRMSE:0.22096
# [74]	Train-rmse:0.01507	Train-PyRMSE:0.21311
# [75]	Train-rmse:0.01488	Train-PyRMSE:0.21037
# [76]	Train-rmse:0.01417	Train-PyRMSE:0.20036
# [77]	Train-rmse:0.01362	Train-PyRMSE:0.19265
# [78]	Train-rmse:0.01314	Train-PyRMSE:0.18588
# [79]	Train-rmse:0.01263	Train-PyRMSE:0.17868
# [80]	Train-rmse:0.01246	Train-PyRMSE:0.17623
# [81]	Train-rmse:0.01228	Train-PyRMSE:0.17369
# [82]	Train-rmse:0.01171	Train-PyRMSE:0.16556
# [83]	Train-rmse:0.01120	Train-PyRMSE:0.15845
# [84]	Train-rmse:0.01081	Train-PyRMSE:0.15289
# [85]	Train-rmse:0.01031	Train-PyRMSE:0.14579
# [86]	Train-rmse:0.00992	Train-PyRMSE:0.14032
# [87]	Train-rmse:0.00976	Train-PyRMSE:0.13809
# [88]	Train-rmse:0.00950	Train-PyRMSE:0.13438
# [89]	Train-rmse:0.00914	Train-PyRMSE:0.12930
# [90]	Train-rmse:0.00878	Train-PyRMSE:0.12417
# [91]	Train-rmse:0.00845	Train-PyRMSE:0.11946
# [92]	Train-rmse:0.00833	Train-PyRMSE:0.11779
# [93]	Train-rmse:0.00816	Train-PyRMSE:0.11542
# [94]	Train-rmse:0.00786	Train-PyRMSE:0.11115
# [95]	Train-rmse:0.00751	Train-PyRMSE:0.10622
# [96]	Train-rmse:0.00742	Train-PyRMSE:0.10500
# [97]	Train-rmse:0.00718	Train-PyRMSE:0.10148
# [98]	Train-rmse:0.00707	Train-PyRMSE:0.10001
# [99]	Train-rmse:0.00685	Train-PyRMSE:0.09681
# [100]	Train-rmse:0.00676	Train-PyRMSE:0.09558
# [101]	Train-rmse:0.00654	Train-PyRMSE:0.09255
# [102]	Train-rmse:0.00628	Train-PyRMSE:0.08888
# [103]	Train-rmse:0.00601	Train-PyRMSE:0.08495
# [104]	Train-rmse:0.00583	Train-PyRMSE:0.08240
# [105]	Train-rmse:0.00576	Train-PyRMSE:0.08150
# [106]	Train-rmse:0.00568	Train-PyRMSE:0.08027
# [107]	Train-rmse:0.00542	Train-PyRMSE:0.07665
# [108]	Train-rmse:0.00521	Train-PyRMSE:0.07373
# [109]	Train-rmse:0.00502	Train-PyRMSE:0.07100
# [110]	Train-rmse:0.00486	Train-PyRMSE:0.06869
# [111]	Train-rmse:0.00468	Train-PyRMSE:0.06612
# [112]	Train-rmse:0.00452	Train-PyRMSE:0.06399
# [113]	Train-rmse:0.00447	Train-PyRMSE:0.06324
# [33]	Train-rmse:0.07150	Train-PyRMSE:1.01120
# [34]	Train-rmse:0.07080	Train-PyRMSE:1.00132
# [35]	Train-rmse:0.06830	Train-PyRMSE:0.96591
# [36]	Train-rmse:0.06769	Train-PyRMSE:0.95733
# [37]	Train-rmse:0.06484	Train-PyRMSE:0.91694
# [38]	Train-rmse:0.06165	Train-PyRMSE:0.87181
# [39]	Train-rmse:0.05937	Train-PyRMSE:0.83965
# [40]	Train-rmse:0.05873	Train-PyRMSE:0.83051
# [41]	Train-rmse:0.05667	Train-PyRMSE:0.80140
# [42]	Train-rmse:0.05596	Train-PyRMSE:0.79141
# [43]	Train-rmse:0.05416	Train-PyRMSE:0.76589
# [44]	Train-rmse:0.05299	Train-PyRMSE:0.74934
# [45]	Train-rmse:0.05052	Train-PyRMSE:0.71453
# [46]	Train-rmse:0.04922	Train-PyRMSE:0.69609
# [47]	Train-rmse:0.04883	Train-PyRMSE:0.69062
# [48]	Train-rmse:0.04610	Train-PyRMSE:0.65199
# [49]	Train-rmse:0.04417	Train-PyRMSE:0.62469
# [50]	Train-rmse:0.04190	Train-PyRMSE:0.59254
# [51]	Train-rmse:0.04114	Train-PyRMSE:0.58181
# [52]	Train-rmse:0.03957	Train-PyRMSE:0.55954
# [53]	Train-rmse:0.03922	Train-PyRMSE:0.55469
# [54]	Train-rmse:0.03852	Train-PyRMSE:0.54478
# [55]	Train-rmse:0.03717	Train-PyRMSE:0.52562
# [56]	Train-rmse:0.03584	Train-PyRMSE:0.50680
# [57]	Train-rmse:0.03429	Train-PyRMSE:0.48498
# [58]	Train-rmse:0.03400	Train-PyRMSE:0.48083
# [59]	Train-rmse:0.03295	Train-PyRMSE:0.46597
# [60]	Train-rmse:0.03237	Train-PyRMSE:0.45773
# [61]	Train-rmse:0.03090	Train-PyRMSE:0.43705
# [62]	Train-rmse:0.02998	Train-PyRMSE:0.42396
# [63]	Train-rmse:0.02848	Train-PyRMSE:0.40283
# [64]	Train-rmse:0.02729	Train-PyRMSE:0.38591
# [65]	Train-rmse:0.02692	Train-PyRMSE:0.38066
# [66]	Train-rmse:0.02617	Train-PyRMSE:0.37015
# [67]	Train-rmse:0.02588	Train-PyRMSE:0.36598
# [68]	Train-rmse:0.02491	Train-PyRMSE:0.35227
# [69]	Train-rmse:0.02429	Train-PyRMSE:0.34345
# [70]	Train-rmse:0.02398	Train-PyRMSE:0.33908
# [71]	Train-rmse:0.02309	Train-PyRMSE:0.32650
# [72]	Train-rmse:0.02219	Train-PyRMSE:0.31381
# [73]	Train-rmse:0.02094	Train-PyRMSE:0.29617
# [74]	Train-rmse:0.02079	Train-PyRMSE:0.29398
# [75]	Train-rmse:0.02028	Train-PyRMSE:0.28685
# [76]	Train-rmse:0.01931	Train-PyRMSE:0.27311
# [77]	Train-rmse:0.01919	Train-PyRMSE:0.27140
# [78]	Train-rmse:0.01862	Train-PyRMSE:0.26335
# [79]	Train-rmse:0.01743	Train-PyRMSE:0.24652
# [80]	Train-rmse:0.01699	Train-PyRMSE:0.24033
# [81]	Train-rmse:0.01644	Train-PyRMSE:0.23255
# [82]	Train-rmse:0.01565	Train-PyRMSE:0.22127
# [83]	Train-rmse:0.01526	Train-PyRMSE:0.21582
# [84]	Train-rmse:0.01503	Train-PyRMSE:0.21257
# [85]	Train-rmse:0.01450	Train-PyRMSE:0.20508
# [86]	Train-rmse:0.01410	Train-PyRMSE:0.19936
# [87]	Train-rmse:0.01349	Train-PyRMSE:0.19079
# [88]	Train-rmse:0.01288	Train-PyRMSE:0.18211
# [89]	Train-rmse:0.01278	Train-PyRMSE:0.18071
# [90]	Train-rmse:0.01220	Train-PyRMSE:0.17252
# [91]	Train-rmse:0.01179	Train-PyRMSE:0.16679
# [92]	Train-rmse:0.01166	Train-PyRMSE:0.16490
# [93]	Train-rmse:0.01132	Train-PyRMSE:0.16008
# [94]	Train-rmse:0.01088	Train-PyRMSE:0.15388
# [95]	Train-rmse:0.01060	Train-PyRMSE:0.14993
# [96]	Train-rmse:0.01006	Train-PyRMSE:0.14229
# [97]	Train-rmse:0.00998	Train-PyRMSE:0.14109
# [98]	Train-rmse:0.00954	Train-PyRMSE:0.13496
# [99]	Train-rmse:0.00948	Train-PyRMSE:0.13406
# [100]	Train-rmse:0.00926	Train-PyRMSE:0.13098
# [101]	Train-rmse:0.00901	Train-PyRMSE:0.12747
# [102]	Train-rmse:0.00885	Train-PyRMSE:0.12510
# [103]	Train-rmse:0.00847	Train-PyRMSE:0.11979
# [104]	Train-rmse:0.00833	Train-PyRMSE:0.11784
# [105]	Train-rmse:0.00791	Train-PyRMSE:0.11187
# [106]	Train-rmse:0.00787	Train-PyRMSE:0.11125
# [107]	Train-rmse:0.00755	Train-PyRMSE:0.10682
# [108]	Train-rmse:0.00724	Train-PyRMSE:0.10244
# [109]	Train-rmse:0.00705	Train-PyRMSE:0.09975
# [110]	Train-rmse:0.00683	Train-PyRMSE:0.09662
# [111]	Train-rmse:0.00656	Train-PyRMSE:0.09274
# [112]	Train-rmse:0.00640	Train-PyRMSE:0.09058
# [113]	Train-rmse:0.00631	Train-PyRMSE:0.08921
# [114]	Train-rmse:0.00626	Train-PyRMSE:0.08859
# [115]	Train-rmse:0.00601	Train-PyRMSE:0.08505
# [116]	Train-rmse:0.00578	Train-PyRMSE:0.08174
# [117]	Train-rmse:0.00562	Train-PyRMSE:0.07944
# [118]	Train-rmse:0.00553	Train-PyRMSE:0.07816
# [119]	Train-rmse:0.00533	Train-PyRMSE:0.07537
# [120]	Train-rmse:0.00513	Train-PyRMSE:0.07261
# [121]	Train-rmse:0.00505	Train-PyRMSE:0.07140
# [122]	Train-rmse:0.00501	Train-PyRMSE:0.07087
# [123]	Train-rmse:0.00488	Train-PyRMSE:0.06904
# [124]	Train-rmse:0.00475	Train-PyRMSE:0.06713
# [125]	Train-rmse:0.00467	Train-PyRMSE:0.06604
# [126]	Train-rmse:0.00446	Train-PyRMSE:0.06301
# [127]	Train-rmse:0.00443	Train-PyRMSE:0.06260

# %%
X, y = gen_circle()

# %%
X
# Out:
# array([[-98.89105638],
#        [-98.36510052],
#        [-96.9058012 ],
#        [-96.52428833],
#        [-94.55023394],
#        [-93.80380651],
#        [-85.74188092],
#        [-84.41704636],
#        [-80.27599363],
#        [-79.54561338],
#        [-79.06287914],
#        [-75.64729245],
#        [-73.7700622 ],
#        [-73.68492724],
#        [-68.86561094],
#        [-67.35892847],
#        [-63.25142889],
#        [-58.25153058],
#        [-56.90715335],
#        [-52.40156691],
#        [-51.94202308],
#        [-51.46392555],
#        [-50.64804949],
#        [-43.4825513 ],
#        [-42.3963994 ],
#        [-42.02647176],
#        [-40.02321624],
#        [-33.39390288],
#        [-32.82867549],
#        [-32.34296083],
#        [-32.08107503],
#        [-30.67614231],
#        [-24.18292095],
#        [-23.43099534],
#        [-22.24758026],
#        [-20.51119628],
#        [-14.04546224],
#        [-11.60736985],
#        [-10.6707162 ],
#        [ -8.41605339],
#        [ -8.07292007],
#        [ -7.96817485],
#        [ -5.50043432],
#        [ -3.49134734],
#        [  1.74258619],
#        [  8.06587435],
#        [  8.91559824],
#        [  9.17723608],
#        [  9.53507442],
#        [ 10.04378191],
#        [ 11.43420808],
#        [ 12.58257066],
#        [ 12.63235706],
#        [ 14.74390825],
#        [ 16.67439589],
#        [ 17.04478853],
#        [ 23.15836368],
#        [ 23.42332628],
#        [ 23.49894279],
#        [ 26.8276444 ],
#        [ 27.12452804],
#        [ 28.6203692 ],
#        [ 30.58533104],
#        [ 31.84740467],
#        [ 32.62474113],
#        [ 34.51843287],
#        [ 39.10343838],
#        [ 39.35267268],
#        [ 39.656438  ],
#        [ 45.26650394],
#        [ 45.28393928],
#        [ 47.29870123],
#        [ 49.74932554],
#        [ 52.83364677],
#        [ 56.93442873],
#        [ 58.66893434],
#        [ 58.70752572],
#        [ 62.66699435],
#        [ 64.87797665],
#        [ 65.1722644 ],
#        [ 65.27470936],
#        [ 65.41262515],
#        [ 73.6524956 ],
#        [ 78.19331123],
#        [ 79.6731346 ],
#        [ 80.80664564],
#        [ 81.26122269],
#        [ 85.5081752 ],
#        [ 87.37454625],
#        [ 89.10014668],
#        [ 89.26947305],
#        [ 89.27432939],
#        [ 89.43654725],
#        [ 90.2110916 ],
#        [ 90.78361622],
#        [ 91.67360328],
#        [ 92.53691843],
#        [ 92.5707556 ],
#        [ 93.21074947],
#        [ 94.10503373]])

# %%
y
# Out:
# array([[0.89432951, 0.4487522 ],
#        [0.87720878, 0.23063895],
#        [0.27516044, 0.07942307],
#        [0.13724641, 0.18966082],
#        [0.35295306, 0.93610646],
#        [0.6304307 , 0.96227881],
#        [0.8617563 , 0.20915315],
#        [0.30777452, 0.06387879],
#        [0.95088811, 0.56829024],
#        [0.88488126, 0.24234879],
#        [0.76921059, 0.05845164],
#        [0.37686751, 0.94287355],
#        [0.95647503, 0.46494442],
#        [0.95252159, 0.4255151 ],
#        [0.60657251, 0.94283236],
#        [0.91418716, 0.39018189],
#        [0.30196543, 0.91685546],
#        [0.03009178, 0.43032728],
#        [0.32827967, 0.92764225],
#        [0.09846894, 0.24223522],
#        [0.        , 0.45201331],
#        [0.0579432 , 0.66102895],
#        [0.31782846, 0.92358228],
#        [0.71475664, 0.90029985],
#        [0.95718782, 0.48460811],
#        [0.99495244, 0.38333291],
#        [0.15201517, 0.1731416 ],
#        [0.0641043 , 0.30725077],
#        [0.0318403 , 0.56492026],
#        [0.11923054, 0.77109737],
#        [0.14003741, 0.78603318],
#        [0.80551458, 0.83553913],
#        [0.87031815, 0.76253986],
#        [0.95325459, 0.43084284],
#        [0.60972993, 0.04126191],
#        [0.00692668, 0.50382093],
#        [0.0279937 , 0.53427715],
#        [0.87278916, 0.75905203],
#        [0.93288809, 0.34303096],
#        [0.0976688 , 0.24350109],
#        [0.06155016, 0.3742475 ],
#        [0.02906972, 0.438586  ],
#        [0.81999661, 0.82173967],
#        [0.65118564, 0.05422629],
#        [0.95038743, 0.41204626],
#        [1.        , 0.43944206],
#        [0.71860191, 0.08510135],
#        [0.60572155, 0.04022991],
#        [0.44038892, 0.0288665 ],
#        [0.22148564, 0.11242653],
#        [0.01429785, 0.73446105],
#        [0.49918153, 0.95717982],
#        [0.52234021, 0.95622762],
#        [0.87413586, 0.22615599],
#        [0.10851219, 0.22706616],
#        [0.04938023, 0.42018711],
#        [0.06344349, 0.30879057],
#        [0.03050341, 0.42730451],
#        [0.02696101, 0.4623246 ],
#        [0.9536598 , 0.43400294],
#        [0.94228912, 0.28244062],
#        [0.33372054, 0.05363591],
#        [0.14786984, 0.80565782],
#        [0.68636025, 0.91456784],
#        [0.92706846, 0.65652185],
#        [0.43642049, 0.0195021 ],
#        [0.95080437, 0.56879023],
#        [0.95564714, 0.45314776],
#        [0.92289012, 0.31611813],
#        [0.93825066, 0.62325658],
#        [0.87962346, 0.57492319],
#        [0.41066049, 0.03313334],
#        [0.26184533, 0.89658339],
#        [0.74423515, 0.10051215],
#        [0.66682843, 0.92302494],
#        [0.88547366, 0.23015351],
#        [0.87902798, 0.2333468 ],
#        [0.4152278 , 0.95092807],
#        [0.9056257 , 0.27856599],
#        [0.82602437, 0.16764597],
#        [0.74394148, 0.11116599],
#        [0.73928397, 0.09735865],
#        [0.03314309, 0.41060531],
#        [0.64976339, 0.05371015],
#        [0.06988626, 0.29438391],
#        [0.09357893, 0.76458156],
#        [0.30170588, 0.91673959],
#        [0.19700281, 0.1311193 ],
#        [0.23257779, 0.87851414],
#        [0.91383156, 0.68795154],
#        [0.87166905, 0.65852214],
#        [0.94146474, 0.61181371],
#        [0.9549683 , 0.53758585],
#        [0.85493363, 0.20043103],
#        [0.63923755, 0.05005133],
#        [0.20482391, 0.12750196],
#        [0.03059694, 0.42663766],
#        [0.0286618 , 0.44227226],
#        [0.09080387, 0.72852764],
#        [0.42540183, 0.95250532]])
